# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler,PowerTransformer
from sklearn.decomposition import PCA
from sklearn.mixture import BayesianGaussianMixture,GaussianMixture
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import metrics
import lightgbm as lgb
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
from sklearn import metrics
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %%
df=pd.read_csv("GiaSMPvaSMPcap2021_GiathitruongSMP.csv", encoding='ISO-8859-1',sep =';')
df.head()
# Out:
#          Ngày       1       2       3       4       5       6       7       8  \
# 0  01/01/2021   964.4   964.4   964.4   964.4   964.4   964.4   964.4   964.4
# 1  01/02/2021  1019.7  1019.7  1019.7  1019.7  1019.7  1019.7  1019.7  1019.7
# 2  01/03/2021   988.4   988.4   988.4   988.4   988.4   988.4   988.4   988.4
# 3  01/04/2021  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0  1002.0
# 4  01/05/2021  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5
#
#         9  ...      39      40      41      42      43      44      45  \
# 0   964.4  ...   964.4   964.4   964.4   964.4   964.4   964.4   964.4
# 1  1019.7  ...  1019.7  1019.7  1019.7  1019.7  1019.7  1019.7  1019.7
# 2   988.4  ...   988.4   988.4   988.4   988.4   988.4   988.4   988.4
# 3  1002.1  ...  1010.8  1010.8  1010.8  1010.8  1010.8  1010.8  1010.8
# 4  1061.5  ...  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5  1061.5
#
#        46      47      48
# 0   964.4   964.4   964.4
# 1  1019.7  1019.7  1019.7
# 2   988.4   988.4   988.4
# 3  1010.8  1010.8  1010.8
# 4  1061.5  1061.5  1061.5
#
# [5 rows x 49 columns]

# %%
new_df= pd.concat([df['Ngày'],df['12']],axis=1)
new_df.head(10)
# Out:
#          Ngày      12
# 0  01/01/2021   964.4
# 1  01/02/2021  1019.7
# 2  01/03/2021   988.4
# 3  01/04/2021  1010.8
# 4  01/05/2021  1061.5
# 5  01/06/2021  1061.5
# 6  01/07/2021  1061.5
# 7  01/08/2021  1061.5
# 8  01/09/2021  1064.1
# 9  01/10/2021   966.7

# %%
feats = ['12']

# %%
from sklearn.preprocessing import PowerTransformer
X = df['12'].values.reshape(-1,1)

transform = PowerTransformer()
X_transformed = transform.fit_transform(X)

# %%
BGM = BayesianGaussianMixture(n_components=7,covariance_type='full',random_state=1,n_init=15)
# mô hình phù hợp và dự đoán cụm
preds = BGM.fit_predict(X)

# them tinh nang cum vao khung du lieu goc
df["Clusters"]= preds

# %%
pp=BGM.predict_proba(X)
# Calcualting the probabilities of each prediction
df_new=pd.DataFrame(X,columns=feats)
df_new[[f'predict_proba_{i}' for i in range(7)]]=pp # creating new dataframe columns of probabilites
df_new['preds']=preds
df_new['predict_proba']=np.max(pp,axis=1)
df_new['predict']=np.argmax(pp,axis=1)

train_index=np.array([])
for n in range(7):
    n_inx=df_new[(df_new.preds==n) & (df_new.predict_proba > 0.68)].index
    train_index = np.concatenate((train_index, n_inx))

# %%
from sklearn.model_selection import StratifiedKFold
X_new=df_new.loc[train_index][feats]
y=df_new.loc[train_index]['preds']
S
params_lgb = {'learning_rate': 0.06,'objective': 'multiclass','boosting': 'gbdt','n_jobs': -1,'verbosity': -1, 'num_classes':7}

model_list=[]

gkf = StratifiedKFold(12)
for fold, (train_idx, valid_idx) in enumerate(gkf.split(X_new,y)):

    tr_dataset = lgb.Dataset(X_new.iloc[train_idx],y.iloc[train_idx],feature_name = feats)
    vl_dataset = lgb.Dataset(X_new.iloc[valid_idx],y.iloc[valid_idx],feature_name = feats)

    model = lgb.train(params = params_lgb,
                train_set = tr_dataset,
                valid_sets =  vl_dataset,
                num_boost_round = 5000,
                callbacks=[ lgb.early_stopping(stopping_rounds=300, verbose=False), lgb.log_evaluation(period=200)])

    model_list.append(model)
# Out:
# [200]	valid_0's multi_logloss: 0.000163493
# [400]	valid_0's multi_logloss: 0.000163493
# [200]	valid_0's multi_logloss: 0.000163024
# [400]	valid_0's multi_logloss: 0.000163024
# [200]	valid_0's multi_logloss: 0.000163331
# [400]	valid_0's multi_logloss: 0.000163331
# [200]	valid_0's multi_logloss: 0.000156806
# [400]	valid_0's multi_logloss: 0.000156806
# [200]	valid_0's multi_logloss: 0.000162715
# [400]	valid_0's multi_logloss: 0.000162715
# [200]	valid_0's multi_logloss: 0.000159771
# [400]	valid_0's multi_logloss: 0.000159771
# [200]	valid_0's multi_logloss: 0.00016652
# [400]	valid_0's multi_logloss: 0.00016652
# [200]	valid_0's multi_logloss: 8.7928e-06
# [400]	valid_0's multi_logloss: 8.73492e-06
# [600]	valid_0's multi_logloss: 8.6978e-06
# [800]	valid_0's multi_logloss: 8.672e-06
# [1000]	valid_0's multi_logloss: 8.65305e-06
# [1200]	valid_0's multi_logloss: 8.63856e-06
# [1400]	valid_0's multi_logloss: 8.62713e-06
# [1600]	valid_0's multi_logloss: 8.61788e-06
# [1800]	valid_0's multi_logloss: 8.61026e-06
# [2000]	valid_0's multi_logloss: 8.60386e-06
# [2200]	valid_0's multi_logloss: 8.59841e-06
# [2400]	valid_0's multi_logloss: 8.59373e-06
# [2600]	valid_0's multi_logloss: 8.58965e-06
# [2800]	valid_0's multi_logloss: 8.58607e-06
# [3000]	valid_0's multi_logloss: 8.5829e-06
# [3200]	valid_0's multi_logloss: 8.58008e-06
# [3400]	valid_0's multi_logloss: 8.57756e-06
# [3600]	valid_0's multi_logloss: 8.57528e-06
# [3800]	valid_0's multi_logloss: 8.57321e-06
# [4000]	valid_0's multi_logloss: 8.57133e-06
# [4200]	valid_0's multi_logloss: 8.56961e-06
# [4400]	valid_0's multi_logloss: 8.56803e-06
# [4600]	valid_0's multi_logloss: 8.56658e-06
# [4800]	valid_0's multi_logloss: 8.56524e-06
# [5000]	valid_0's multi_logloss: 8.564e-06
# [200]	valid_0's multi_logloss: 0.000166496
# [400]	valid_0's multi_logloss: 0.000166496
# [200]	valid_0's multi_logloss: 0.000160773
# [400]	valid_0's multi_logloss: 0.000160773
# [200]	valid_0's multi_logloss: 0.0263001
# [200]	valid_0's multi_logloss: 0.0132594
# [400]	valid_0's multi_logloss: 0.0132594

# %%
lgb_preds=0
for model in model_list:
    lgb_preds+=model.predict(df_new[feats])

# %%
labels=np.argmax(lgb_preds,axis=1)

# %%
import numpy as np
# Tính chuỗi return
r_t = np.log(new_df['12'] / new_df['12'].shift(1)).values

# %%
mean = np.nanmean(r_t)
r_t[0]=mean
r_t[:5]
# Out:
# array([ 0.00016098,  0.0557576 , -0.03117627,  0.0224099 ,  0.04894091])

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(r_t)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -9.350863
# p-value: 0.000000
# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 6))
ax1 = plot_acf(r_t,color='orange')

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 6))
ax2 = plot_pacf(r_t)

# %%
from statsmodels.tsa.arima.model import ARIMA

# Khởi tạo và phù hợp với mô hình ARIMA
model_arima = ARIMA(r_t, order=(2, 0, 2))
model_fit = model_arima.fit()

# In ra tóm tắt của mô hình
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                 ARIMA(2, 0, 2)   Log Likelihood                 563.223
# Date:                Tue, 07 May 2024   AIC                          -1114.446
# Time:                        04:44:20   BIC                          -1091.047
# Sample:                             0   HQIC                         -1105.147
#                                 - 365
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.829e-06      0.001     -0.006      0.995      -0.002       0.002
# ar.L1         -0.1328      0.059     -2.233      0.026      -0.249      -0.016
# ar.L2          0.5723      0.054     10.593      0.000       0.466       0.678
# ma.L1         -0.0099      0.040     -0.249      0.804      -0.087       0.068
# ma.L2         -0.8488      0.043    -19.543      0.000      -0.934      -0.764
# sigma2         0.0027      0.000     25.500      0.000       0.002       0.003
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):               665.01
# Prob(Q):                              0.61   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.72   Skew:                             0.50
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
df['Ngày'] = pd.to_datetime(df['Ngày'], format='%d/%m/%Y')
df.sort_values(by='Ngày', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
test_size = df[df['Ngày'].dt.month==12].shape[0]
test_size
# Out:
# 31

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'gray'
plt.rc('axes',edgecolor='white')
plt.plot(df['Ngày'][:-test_size], df['10'][:-test_size], color='red', lw=2)
plt.plot(df['Ngày'][-test_size:], df['10'][-test_size:], color='pink', lw=2)
plt.title('10', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('10', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
